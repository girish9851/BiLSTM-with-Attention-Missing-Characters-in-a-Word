# %%
import os
import random

# %%
os.listdir('../input/')
# Out:
# ['bilstm-attention-hangman',
#  'model-input',
#  'dataset-inputs',
#  'best-model2',
#  'input-data']

# %%
# os.listdir('.')
# os.listdir('../input/input-data/')

# %%
### read words ###
text_file = open('../input/input-data/words_250000_train.txt',"r")
full_dictionary = text_file.read().splitlines()

# %%
import numpy as np

random.seed(40)

import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

random.seed(40)

# Sample data for demonstration
words = full_dictionary

def generate_training_data_3(words):
    X = []
    y = []
    for word in words:
      # print(word)
      for char in np.unique(list(word)):
          X.append(word.replace(char,"_"))  # Input with missing character
          y.append(char)
          try:
            X.append(word.replace(char,"_").replace(random.choice(list(word.replace(char,""))),"_"))  # Input with missing character
            y.append(char)                      # Target character (the missing one)
          except:
            pass
          # print(word.replace(char,"_"))
    return X, y


# Toy dataset
X_train_3, y_train_3 = generate_training_data_3(words)

words_3 = X_train_3
labels_3 = y_train_3

max_length_3 = max(len(word) for word in words_3)

# Create a dictionary for character to index mapping
char_to_index = {char: idx for idx, char in enumerate(set(''.join(words_3)))}
index_to_char = {idx: char for char, idx in char_to_index.items()}

# Convert words and labels to numerical format
X_padded_3 = pad_sequences([[char_to_index[char] for char in word] for word in words_3], maxlen=max_length_3, padding='post')
y_padded_3 = np.array([char_to_index[label] for label in labels_3])

X_train_3, X_temp_3, y_train_3, y_temp_3 = train_test_split(X_padded_3, y_padded_3, test_size=0.3, random_state=42)
X_val_3, X_test_3, y_val_3, y_test_3 = train_test_split(X_temp_3, y_temp_3, test_size=0.5, random_state=42)

# print("Padded data:")
# for i in range(len(words)):
#     print(f"{words[i]} -> {labels[i]}")

# print("\nPadded and numerical data:")
# print(X_padded_2)
# print(y_padded_2)
# Out:
# 2024-06-23 09:11:58.030390: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-23 09:11:58.030517: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-23 09:11:58.155272: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # BiLSTM with attention
#
# ## attention
#
# ## LSTM 256
#
# ## embedding - 50
#
# ## no dropout

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

# Define a checkpoint callback
checkpoint_callback_6 = ModelCheckpoint('best_model_6.keras', 
                                      monitor='val_loss', 
                                      save_best_only=True, 
                                      mode='min', 
                                      verbose=1)

early_stopping_callback = EarlyStopping(monitor='val_loss', 
                                       patience=3, 
                                       mode='min', 
                                       verbose=1)

# %%
# # detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver()

# # instantiate a distribution strategy
# tf.tpu.experimental.initialize_tpu_system(tpu)
# tpu_strategy = tf.distribute.TPUStrategy(tpu)

# # instantiating the model in the strategy scope creates the model on the TPU

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout, Concatenate, Layer
from tensorflow.keras import Input, Model
import keras
# Define parameters
vocab_size = len(char_to_index)  # Size of vocabulary (unique characters)
embedding_dim = 50  # Dimension of character embeddings
lstm_units = 256  # Number of units in LSTM layers
num_layers = 3  # Number of BiLSTM layers
dropout_rate = 0.1  # Dropout rate

# Custom Attention Layer
@keras.saving.register_keras_serializable()
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1),
                                 initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1),
                                 initializer="zeros")

        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        et = tf.squeeze(tf.tanh(tf.matmul(x, self.W) + self.b), axis=-1)
        at = tf.nn.softmax(et)
        at = tf.expand_dims(at, axis=-1)
        output = x * at
        return tf.reduce_sum(output, axis=1)

# Define Sequential model
model_6 = Sequential()

# Add layers to the model
model_6.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length_3))

# Add BiLSTM layers with Dropout
for _ in range(num_layers):
    model_6.add(Bidirectional(LSTM(units=lstm_units, return_sequences=True)))
    model_6.add(Dropout(rate=dropout_rate))

# Add Attention Layer
model_6.add(AttentionLayer())

# Output layer
model_6.add(Dense(units=vocab_size, activation='softmax'))

# Compile the model
model_6.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model_6.summary()

# %%
# Train the model
model_6.fit( X_train_3, 
            y_train_3, 
            epochs=3, 
            batch_size=256, 
            validation_data=(X_val_3, y_val_3), 
            verbose=1,callbacks=[checkpoint_callback_6,early_stopping_callback])
# Out:
# Epoch 1/3
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3576 - loss: 2.0250
# Epoch 1: val_loss improved from inf to 1.46096, saving model to best_model_6.keras
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 628s 67ms/step - accuracy: 0.3576 - loss: 2.0249 - val_accuracy: 0.5023 - val_loss: 1.4610
# Epoch 2/3
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5176 - loss: 1.4068
# Epoch 2: val_loss improved from 1.46096 to 1.34231, saving model to best_model_6.keras
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 621s 68ms/step - accuracy: 0.5176 - loss: 1.4068 - val_accuracy: 0.5338 - val_loss: 1.3423
# Epoch 3/3
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5556 - loss: 1.2739
# Epoch 3: val_loss improved from 1.34231 to 1.29647, saving model to best_model_6.keras
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 618s 67ms/step - accuracy: 0.5556 - loss: 1.2739 - val_accuracy: 0.5456 - val_loss: 1.2965

# %%
# Train the model
model_6.fit( X_train_3, 
            y_train_3, 
            epochs=7, 
            batch_size=256, 
            validation_data=(X_val_3, y_val_3), 
            verbose=1,callbacks=[checkpoint_callback_6,early_stopping_callback])
# Out:
# Epoch 1/7
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5770 - loss: 1.2009
# Epoch 1: val_loss improved from 1.29647 to 1.26940, saving model to best_model_6.keras
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 618s 67ms/step - accuracy: 0.5770 - loss: 1.2009 - val_accuracy: 0.5522 - val_loss: 1.2694
# Epoch 2/7
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5918 - loss: 1.1516
# Epoch 2: val_loss improved from 1.26940 to 1.26491, saving model to best_model_6.keras
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 617s 67ms/step - accuracy: 0.5918 - loss: 1.1516 - val_accuracy: 0.5558 - val_loss: 1.2649
# Epoch 3/7
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6027 - loss: 1.1156
# Epoch 3: val_loss improved from 1.26491 to 1.25808, saving model to best_model_6.keras
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 618s 67ms/step - accuracy: 0.6027 - loss: 1.1156 - val_accuracy: 0.5575 - val_loss: 1.2581
# Epoch 4/7
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6109 - loss: 1.0910
# Epoch 4: val_loss improved from 1.25808 to 1.25142, saving model to best_model_6.keras
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 617s 67ms/step - accuracy: 0.6109 - loss: 1.0910 - val_accuracy: 0.5579 - val_loss: 1.2514
# Epoch 5/7
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6179 - loss: 1.0693
# Epoch 5: val_loss improved from 1.25142 to 1.24678, saving model to best_model_6.keras
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 618s 67ms/step - accuracy: 0.6179 - loss: 1.0693 - val_accuracy: 0.5600 - val_loss: 1.2468
# Epoch 6/7
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6221 - loss: 1.0548
# Epoch 6: val_loss did not improve from 1.24678
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 617s 67ms/step - accuracy: 0.6221 - loss: 1.0548 - val_accuracy: 0.5597 - val_loss: 1.2529
# Epoch 7/7
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6271 - loss: 1.0404
# Epoch 7: val_loss did not improve from 1.24678
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 621s 67ms/step - accuracy: 0.6271 - loss: 1.0404 - val_accuracy: 0.5599 - val_loss: 1.2528

# %%
# checkpoint_callback_total6 = ModelCheckpoint('best_model_6.keras', 
#                                       monitor='val_loss', 
#                                       save_best_only=True, 
#                                       mode='min', 
#                                       verbose=1)

# %%
# Train the model
model_6.fit(X_train_3, 
            y_train_3, 
            epochs=3,      
            batch_size=256,                     
            validation_data=(X_val_3, y_val_3), 
            verbose=1,
            callbacks=[checkpoint_callback_6,early_stopping_callback])
# Out:
# Epoch 1/3
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6297 - loss: 1.0308
# Epoch 1: val_loss did not improve from 1.24678
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 622s 68ms/step - accuracy: 0.6297 - loss: 1.0308 - val_accuracy: 0.5604 - val_loss: 1.2492
# Epoch 2/3
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6336 - loss: 1.0203
# Epoch 2: val_loss did not improve from 1.24678
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 629s 68ms/step - accuracy: 0.6336 - loss: 1.0203 - val_accuracy: 0.5600 - val_loss: 1.2582
# Epoch 3/3
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6364 - loss: 1.0107
# Epoch 3: val_loss did not improve from 1.24678
# 9194/9194 ━━━━━━━━━━━━━━━━━━━━ 621s 67ms/step - accuracy: 0.6364 - loss: 1.0107 - val_accuracy: 0.5600 - val_loss: 1.2575
# Epoch 3: early stopping

# %% [markdown]
# # Complete Training data
# # randome shuffling

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout, Concatenate, Layer
from tensorflow.keras import Input, Model
import keras
# Define parameters
vocab_size = len(char_to_index)  # Size of vocabulary (unique characters)
embedding_dim = 50  # Dimension of character embeddings
lstm_units = 256  # Number of units in LSTM layers
num_layers = 3  # Number of BiLSTM layers
dropout_rate = 0.1  # Dropout rate

# Custom Attention Layer
@keras.saving.register_keras_serializable()
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1),
                                 initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1),
                                 initializer="zeros")

        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        et = tf.squeeze(tf.tanh(tf.matmul(x, self.W) + self.b), axis=-1)
        at = tf.nn.softmax(et)
        at = tf.expand_dims(at, axis=-1)
        output = x * at
        return tf.reduce_sum(output, axis=1)

# Define Sequential model
model_complete_6 = Sequential()

# Add layers to the model
model_complete_6.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length_3))

# Add BiLSTM layers with Dropout
for _ in range(num_layers):
    model_complete_6.add(Bidirectional(LSTM(units=lstm_units, return_sequences=True)))
    model_complete_6.add(Dropout(rate=dropout_rate))

# Add Attention Layer
model_complete_6.add(AttentionLayer())

# Output layer
model_complete_6.add(Dense(units=vocab_size, activation='softmax'))

# Compile the model
model_complete_6.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model_complete_6.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_6 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_7 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_8 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_layer_2               │ ?                      │   0 (unbuilt) │
# │ (AttentionLayer)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.utils import shuffle

X_train_complete_3, y_train_complete_3 = shuffle( X_padded_3, y_padded_3 )

# Train the model
model_complete_6.fit( X_train_complete_3, 
            y_train_complete_3,
            epochs=8, 
            batch_size=256, 
#             validation_data=(X_val_3, y_val_3), 
            verbose=1,
#             callbacks=[checkpoint_callback_6,early_stopping_callback]
           )
# Out:
# Epoch 1/8
# 13135/13135 ━━━━━━━━━━━━━━━━━━━━ 830s 63ms/step - accuracy: 0.3843 - loss: 1.9180
# Epoch 2/8
# 13135/13135 ━━━━━━━━━━━━━━━━━━━━ 823s 63ms/step - accuracy: 0.5356 - loss: 1.3418
# Epoch 3/8
# 13135/13135 ━━━━━━━━━━━━━━━━━━━━ 824s 63ms/step - accuracy: 0.5648 - loss: 1.2346
# Epoch 4/8
# 13135/13135 ━━━━━━━━━━━━━━━━━━━━ 827s 63ms/step - accuracy: 0.5810 - loss: 1.1759
# Epoch 5/8
# 13135/13135 ━━━━━━━━━━━━━━━━━━━━ 821s 63ms/step - accuracy: 0.5912 - loss: 1.1411
# Epoch 6/8
# 13135/13135 ━━━━━━━━━━━━━━━━━━━━ 830s 63ms/step - accuracy: 0.5983 - loss: 1.1167
# Epoch 7/8
# 13135/13135 ━━━━━━━━━━━━━━━━━━━━ 831s 63ms/step - accuracy: 0.6037 - loss: 1.0979
# Epoch 8/8
# 13135/13135 ━━━━━━━━━━━━━━━━━━━━ 833s 63ms/step - accuracy: 0.6080 - loss: 1.0840

# %%
model_complete_6.save('best_model_6_complete.keras')

# %%
model_complete_6_recon = tf.keras.models.load_model('best_model_6_complete.keras')

# %%
# model_complete_6_recon = tf.keras.models.load_model('best_model_6_complete.keras')

# %%
## load model 
# model_6_recon = tf.keras.models.load_model('best_model_6.keras')

# %%
# Evaluate on test set
loss, accuracy = model_complete_6_recon.evaluate(X_test_3, y_test_3, verbose=1)
print(f"validation set Accuracy: {accuracy*100:.2f}%")
# Out:
# 15762/15762 ━━━━━━━━━━━━━━━━━━━━ 137s 9ms/step - accuracy: 0.6346 - loss: 1.0046
# validation set Accuracy: 63.64%

# %%
# Evaluate on test set
loss, accuracy = model_6_recon.evaluate(X_test_3, y_test_3, verbose=1)
print(f"validation set Accuracy: {accuracy*100:.2f}%")
# Out:
# 15762/15762 ━━━━━━━━━━━━━━━━━━━━ 135s 8ms/step - accuracy: 0.5564 - loss: 1.2554
# validation set Accuracy: 55.77%

# %%
def _get_prediction(word):
    
    X_exp = pad_sequences([[char_to_index[char] for char in word]], maxlen=max_length_3, padding='post')
    
    chars = [index_to_char.get(index) for index in np.argsort(model_complete_6_recon.predict(X_exp)[0]) if index_to_char.get(index)!='_']

    return chars[::-1]

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        full_dictionary_location = "../input/input-data/words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        
        self.current_dictionary = []
        
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com', 'https://sg.trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        
        clean_word = word[::2]
        
        guess_letters = _get_prediction(clean_word)
        
        i =0
        
        while guess_letters[i] in self.guessed_letters:
            i = i+1      
        
        return guess_letters[i]

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %%
api = HangmanAPI(access_token="62ccb125e1c1ce89a46eef251ca63c", timeout=2000)

# %%
# api.start_game(practice=1,verbose=True)
# [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
# practice_success_rate = total_practice_successes / total_practice_runs
# print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))

# %%
count = 0
while count < 1000:
    api.start_game(practice=1)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = total_practice_successes / total_practice_runs
    print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
    count = count + 1
    print(count,' of 1000')
# Out:
# Successfully start a new game! Game ID: 433b2615c5e3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: s
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: e
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: o
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ o _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ o _ i _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ o _ i n _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: g
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ o _ i n g '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o t o _ i n g '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': '433b2615c5e3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o t o r i n g '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: m
# Sever response: {'game_id': '433b2615c5e3', 'status': 'success', 'tries_remains': 3, 'word': 'm o t o r i n g '}
# Successfully finished game: 433b2615c5e3
# run 2389 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 1  of 1000
# Successfully start a new game! Game ID: bbbc8c064090. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Guessing letter: s
# Sever response: {'game_id': 'bbbc8c064090', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ s _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: e
# Sever response: {'game_id': 'bbbc8c064090', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ s e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': 'bbbc8c064090', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ i s e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': 'bbbc8c064090', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e _ i s e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: p
# Sever response: {'game_id': 'bbbc8c064090', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p r e _ i s e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: m
# Sever response: {'game_id': 'bbbc8c064090', 'status': 'success', 'tries_remains': 6, 'word': 'p r e m i s e s '}
# Successfully finished game: bbbc8c064090
# run 2390 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 2  of 1000
# Successfully start a new game! Game ID: 373d5be14497. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ i e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ i e r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ i e r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: b
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ i e r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ i e r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ i e r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': '373d5be14497', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ _ i e r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: m
# Sever response: {'game_id': '373d5be14497', 'status': 'failed', 'tries_remains': 0, 'word': '_ a _ _ i e r '}
# Failed game: 373d5be14497. Because of: # of tries exceeded!
# run 2391 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 3  of 1000
# Successfully start a new game! Game ID: 602d75e3e55b. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': '602d75e3e55b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: n
# Sever response: {'game_id': '602d75e3e55b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: s
# Sever response: {'game_id': '602d75e3e55b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': '602d75e3e55b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: l
# Sever response: {'game_id': '602d75e3e55b', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': '602d75e3e55b', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: m
# Sever response: {'game_id': '602d75e3e55b', 'status': 'failed', 'tries_remains': 0, 'word': '_ a _ _ a _ '}
# Failed game: 602d75e3e55b. Because of: # of tries exceeded!
# run 2392 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 4  of 1000
# Successfully start a new game! Game ID: b18b4c19d405. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: e
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: d
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r e _ _ e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: p
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ _ e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p r e _ _ e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p r e _ _ e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: g
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'ongoing', 'tries_remains': 1, 'word': 'p r e _ _ e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: c
# Sever response: {'game_id': 'b18b4c19d405', 'status': 'failed', 'tries_remains': 0, 'word': 'p r e _ _ e d '}
# Failed game: b18b4c19d405. Because of: # of tries exceeded!
# run 2393 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 5  of 1000
# Successfully start a new game! Game ID: 19da9c469e89. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ e _ _ _ _ _ _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ i _ e _ _ e _ _ _ _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ i _ e _ _ e _ _ a _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: n
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a n _ i _ e _ _ e n _ a _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: v
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a n _ i _ e _ _ e n _ a _ i v e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a n t i _ e _ _ e n t a t i v e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a n t i _ e r _ e n t a t i v e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: p
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n t i _ e r _ e n t a t i v e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: m
# Sever response: {'game_id': '19da9c469e89', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n t i _ e r m e n t a t i v e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: f
# Sever response: {'game_id': '19da9c469e89', 'status': 'success', 'tries_remains': 5, 'word': 'a n t i f e r m e n t a t i v e '}
# Successfully finished game: 19da9c469e89
# run 2394 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 6  of 1000
# Successfully start a new game! Game ID: 78d44f0ff701. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': '78d44f0ff701', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '78d44f0ff701', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a _ _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: b
# Sever response: {'game_id': '78d44f0ff701', 'status': 'ongoing', 'tries_remains': 6, 'word': 'b _ _ a b _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: u
# Sever response: {'game_id': '78d44f0ff701', 'status': 'ongoing', 'tries_remains': 5, 'word': 'b _ _ a b _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '78d44f0ff701', 'status': 'ongoing', 'tries_remains': 5, 'word': 'b i _ a b _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: l
# Sever response: {'game_id': '78d44f0ff701', 'status': 'ongoing', 'tries_remains': 5, 'word': 'b i _ a b l e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': '78d44f0ff701', 'status': 'success', 'tries_remains': 5, 'word': 'b i t a b l e '}
# Successfully finished game: 78d44f0ff701
# run 2395 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 7  of 1000
# Successfully start a new game! Game ID: 8016768aab7a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': '8016768aab7a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '8016768aab7a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '8016768aab7a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a e _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': '8016768aab7a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ a e _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': '8016768aab7a', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ a e _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: p
# Sever response: {'game_id': '8016768aab7a', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ a e _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': '8016768aab7a', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ a e _ a l '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: h
# Sever response: {'game_id': '8016768aab7a', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ a e _ a l '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '8016768aab7a', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ a e _ a l '}
# Failed game: 8016768aab7a. Because of: # of tries exceeded!
# run 2396 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 8  of 1000
# Successfully start a new game! Game ID: 46e1441b6069. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '46e1441b6069', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Guessing letter: e
# Sever response: {'game_id': '46e1441b6069', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '46e1441b6069', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ i _ i _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '46e1441b6069', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ n i _ i _ n '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: o
# Sever response: {'game_id': '46e1441b6069', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ n i _ i _ n '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': '46e1441b6069', 'status': 'ongoing', 'tries_remains': 4, 'word': 't e _ _ n i _ i _ n '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': '46e1441b6069', 'status': 'ongoing', 'tries_remains': 4, 'word': 't e _ _ n i _ i a n '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: h
# Sever response: {'game_id': '46e1441b6069', 'status': 'ongoing', 'tries_remains': 4, 'word': 't e _ h n i _ i a n '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: c
# Sever response: {'game_id': '46e1441b6069', 'status': 'success', 'tries_remains': 4, 'word': 't e c h n i c i a n '}
# Successfully finished game: 46e1441b6069
# run 2397 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 9  of 1000
# Successfully start a new game! Game ID: fd24069acc8f. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: s
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: e
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ _ _ e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ _ _ _ e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: n
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ _ _ _ e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ _ _ e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: p
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ p p e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ i p p e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ i p p e r _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: y
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ i p p e r y '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: k
# Sever response: {'game_id': 'fd24069acc8f', 'status': 'success', 'tries_remains': 3, 'word': 's k i p p e r y '}
# Successfully finished game: fd24069acc8f
# run 2398 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 10  of 1000
# Successfully start a new game! Game ID: 19c0ebee1e81. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: e
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: s
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: i
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ i _ _ _ i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ i _ a _ i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: o
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ i _ a _ i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ i _ a _ i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: l
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l _ _ _ _ i _ a l i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: c
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l _ _ _ _ i c a l i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: p
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l _ _ _ _ i c a l i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: y
# Sever response: {'game_id': '19c0ebee1e81', 'status': 'failed', 'tries_remains': 0, 'word': 'l _ _ _ _ i c a l i s '}
# Failed game: 19c0ebee1e81. Because of: # of tries exceeded!
# run 2399 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 11  of 1000
# Successfully start a new game! Game ID: 3ccee3092eec. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: a
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ _ a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: i
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: o
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ o _ _ _ _ i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ o _ _ _ _ i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: c
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ o c _ _ _ i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: l
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ o c _ _ _ i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: y
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ y _ o c _ _ _ i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: p
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ y p o c _ _ _ i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: h
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h y p o c h _ _ i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': '3ccee3092eec', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h y p o c h _ r i a '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: u
# Sever response: {'game_id': '3ccee3092eec', 'status': 'failed', 'tries_remains': 0, 'word': 'h y p o c h _ r i a '}
# Failed game: 3ccee3092eec. Because of: # of tries exceeded!
# run 2400 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 12  of 1000
# Successfully start a new game! Game ID: 6cf085e4e82e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: p
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p _ _ _ _ _ _ _ _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p _ _ _ _ _ _ _ _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p _ _ l l _ _ l _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: c
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p _ _ l l _ c l _ _ _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Guessing letter: u
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p _ _ l l _ c l _ _ _ u s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: o
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p _ _ l l o c l _ _ o u s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'p _ _ l l o c l _ _ o u s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: y
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'p _ y l l o c l _ _ o u s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'p _ y l l o c l a _ o u s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: d
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'p _ y l l o c l a d o u s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: h
# Sever response: {'game_id': '6cf085e4e82e', 'status': 'success', 'tries_remains': 1, 'word': 'p h y l l o c l a d o u s '}
# Successfully finished game: 6cf085e4e82e
# run 2401 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 13  of 1000
# Successfully start a new game! Game ID: b62646775c25. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: e
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: s
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: t
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: d
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ d _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: p
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p _ _ _ _ _ _ _ d _ _ _ _ _ p _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: o
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p _ o _ o _ _ _ d _ o _ _ _ p _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p _ o _ o _ a _ d _ o _ _ a p _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: y
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p _ o _ o _ a _ d _ o _ _ a p _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p _ o _ o _ a r d _ o _ r a p _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: g
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p _ o _ o _ a r d _ o g r a p _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: h
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p h o _ o _ a r d _ o g r a p h '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: c
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p h o _ o c a r d _ o g r a p h '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': 'b62646775c25', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p h o _ o c a r d i o g r a p h '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': 'b62646775c25', 'status': 'success', 'tries_remains': 2, 'word': 'p h o n o c a r d i o g r a p h '}
# Successfully finished game: b62646775c25
# run 2402 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 14  of 1000
# Successfully start a new game! Game ID: cbfb4d03acb1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ _ e _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: o
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 6, 'word': 'o _ _ _ _ o _ e _ _ e _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 6, 'word': 'o _ _ _ _ o _ e _ _ e s _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 6, 'word': 'o _ _ _ i o _ e _ _ e s i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: p
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ _ _ i o _ e _ _ e s i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ _ r i o _ e _ _ e s i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ _ r i o _ e n _ e s i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ _ r i o _ e n t e s i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o _ a r i o _ e n t e s i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: v
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'ongoing', 'tries_remains': 5, 'word': 'o v a r i o _ e n t e s i s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: c
# Sever response: {'game_id': 'cbfb4d03acb1', 'status': 'success', 'tries_remains': 5, 'word': 'o v a r i o c e n t e s i s '}
# Successfully finished game: cbfb4d03acb1
# run 2403 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 15  of 1000
# Successfully start a new game! Game ID: 3ebab8ba761a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ s _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ s e _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: o
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ o o s e _ o _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ o o s e _ o _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: n
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o o s e _ o _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: u
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o o s e _ o u _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o o s e _ o u _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: h
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o o s e _ o u _ h '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: g
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'g o o s e _ o u _ h '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'g o o s e _ o u t h '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: m
# Sever response: {'game_id': '3ebab8ba761a', 'status': 'success', 'tries_remains': 3, 'word': 'g o o s e m o u t h '}
# Successfully finished game: 3ebab8ba761a
# run 2404 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 16  of 1000
# Successfully start a new game! Game ID: 70e90793da46. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ _ _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ e _ _ _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ e _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: o
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ o _ e _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ o _ e _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: n
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ o _ e _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ o _ e r i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: v
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ o _ e r i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: p
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ _ o _ e r i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: l
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a l l o _ e r i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: m
# Sever response: {'game_id': '70e90793da46', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a l l o m e r i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: z
# Sever response: {'game_id': '70e90793da46', 'status': 'success', 'tries_remains': 1, 'word': 'a l l o m e r i z e '}
# Successfully finished game: 70e90793da46
# run 2405 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 17  of 1000
# Successfully start a new game! Game ID: 241a52dfc9ea. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e s _ e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e s _ e _ r e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e s _ e _ r e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: d
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e s _ e _ r e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e s _ e a r e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: w
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e s _ e a r e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: b
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b e s _ e a r e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: p
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'ongoing', 'tries_remains': 2, 'word': 'b e s _ e a r e d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: m
# Sever response: {'game_id': '241a52dfc9ea', 'status': 'success', 'tries_remains': 2, 'word': 'b e s m e a r e d '}
# Successfully finished game: 241a52dfc9ea
# run 2406 practice games out of an allotted 100,000. practice success rate so far = 0.606
# 18  of 1000
# Successfully start a new game! Game ID: aaab82dbb96e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: s
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'ongoing', 'tries_remains': 4, 'word': 't _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: d
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'ongoing', 'tries_remains': 4, 'word': 't _ _ _ _ _ _ _ d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: l
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'ongoing', 'tries_remains': 4, 'word': 't _ _ l _ _ _ _ d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: p
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'ongoing', 'tries_remains': 3, 'word': 't _ _ l _ _ _ _ d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'ongoing', 'tries_remains': 2, 'word': 't _ _ l _ _ _ _ d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: w
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'ongoing', 'tries_remains': 1, 'word': 't _ _ l _ _ _ _ d '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': 'aaab82dbb96e', 'status': 'failed', 'tries_remains': 0, 'word': 't _ _ l _ _ _ _ d '}
# Failed game: aaab82dbb96e. Because of: # of tries exceeded!
# run 2407 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 19  of 1000
# Successfully start a new game! Game ID: 291d1bf91324. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: e
# Sever response: {'game_id': '291d1bf91324', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': '291d1bf91324', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: o
# Sever response: {'game_id': '291d1bf91324', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ o _ e _ o _ o _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '291d1bf91324', 'status': 'ongoing', 'tries_remains': 5, 'word': 's o _ e _ o _ o _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': '291d1bf91324', 'status': 'ongoing', 'tries_remains': 4, 'word': 's o _ e _ o _ o _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: n
# Sever response: {'game_id': '291d1bf91324', 'status': 'ongoing', 'tries_remains': 4, 'word': 's o _ e n o _ o n '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': '291d1bf91324', 'status': 'ongoing', 'tries_remains': 4, 'word': 's o l e n o _ o n '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: d
# Sever response: {'game_id': '291d1bf91324', 'status': 'success', 'tries_remains': 4, 'word': 's o l e n o d o n '}
# Successfully finished game: 291d1bf91324
# run 2408 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 20  of 1000
# Successfully start a new game! Game ID: d027a44537c5. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': 'd027a44537c5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ a _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': 'd027a44537c5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ a _ _ _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': 'd027a44537c5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ a _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: n
# Sever response: {'game_id': 'd027a44537c5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a n a _ i _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Guessing letter: t
# Sever response: {'game_id': 'd027a44537c5', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a n a _ i t e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': 'd027a44537c5', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n a _ i t e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: r
# Sever response: {'game_id': 'd027a44537c5', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a n a _ i t e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': 'd027a44537c5', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a n a _ i t e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: m
# Sever response: {'game_id': 'd027a44537c5', 'status': 'success', 'tries_remains': 3, 'word': 'a n a m i t e '}
# Successfully finished game: d027a44537c5
# run 2409 practice games out of an allotted 100,000. practice success rate so far = 0.606
# 21  of 1000
# Successfully start a new game! Game ID: 42174a013f78. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: a
# Sever response: {'game_id': '42174a013f78', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '42174a013f78', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ e _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: y
# Sever response: {'game_id': '42174a013f78', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ e _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': '42174a013f78', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ e _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '42174a013f78', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ e _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': '42174a013f78', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ e _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': '42174a013f78', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e _ e _ _ s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': '42174a013f78', 'status': 'failed', 'tries_remains': 0, 'word': 'e _ e _ _ s '}
# Failed game: 42174a013f78. Because of: # of tries exceeded!
# run 2410 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 22  of 1000
# Successfully start a new game! Game ID: d82d83837cab. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ s _ _ _ s _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s _ _ _ s _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ s _ _ _ s _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: d
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd _ s _ _ _ s _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd i s _ _ i s _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: o
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd i s _ _ i s _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: l
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd i s _ _ i s _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd i s _ _ i s a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: u
# Sever response: {'game_id': 'd82d83837cab', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd i s _ u i s a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: q
# Sever response: {'game_id': 'd82d83837cab', 'status': 'failed', 'tries_remains': 0, 'word': 'd i s _ u i s a _ '}
# Failed game: d82d83837cab. Because of: # of tries exceeded!
# run 2411 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 23  of 1000
# Successfully start a new game! Game ID: a337e0954903. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: s
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ _ e _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ _ _ e _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ _ _ e t _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ _ _ e t _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: c
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ _ e t _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ _ _ e t _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ i _ e t _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: y
# Sever response: {'game_id': 'a337e0954903', 'status': 'ongoing', 'tries_remains': 1, 'word': 's _ i _ e t _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ...
# Failed game: ef0a6fa4a8a5. Because of: # of tries exceeded!
# run 2455 practice games out of an allotted 100,000. practice success rate so far = 0.604
# 67  of 1000
# Successfully start a new game! Game ID: 25ab008ada0d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ _ _ _ _ e _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ _ _ _ _ _ _ e _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ _ _ _ i _ _ e _ _ _ _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: o
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ o _ _ _ i _ _ e _ _ _ _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ e _ o _ _ _ i _ _ e _ _ a _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: t
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ e t o _ _ _ i _ _ e _ _ a _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ n e t o _ _ _ i _ _ e _ _ a n i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: c
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ n e t o _ _ _ i _ _ e c _ a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: p
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ n e t o _ _ _ i _ _ e c _ a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: r
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ n e t o _ _ _ i _ _ e c _ a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: h
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ n e t o _ _ _ i _ _ e c h a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: u
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ n e t o _ _ u i _ _ e c h a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: m
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'm a _ n e t o _ _ u i _ m e c h a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'm a _ n e t o _ l u i _ m e c h a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: g
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'm a g n e t o _ l u i _ m e c h a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: b
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 2, 'word': 'm a g n e t o _ l u i _ m e c h a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: f
# Sever response: {'game_id': '25ab008ada0d', 'status': 'ongoing', 'tries_remains': 2, 'word': 'm a g n e t o f l u i _ m e c h a n i c '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: d
# Sever response: {'game_id': '25ab008ada0d', 'status': 'success', 'tries_remains': 2, 'word': 'm a g n e t o f l u i d m e c h a n i c '}
# Successfully finished game: 25ab008ada0d
# run 2456 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 68  of 1000
# Successfully start a new game! Game ID: 8b9076c2aa73. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: e
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: o
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: u
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ e u _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ e u _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ _ _ _ a _ e u _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ i _ _ a _ e u _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: c
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ i _ _ a _ e u _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ i t _ a _ e u _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a r _ i t r a _ e u r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: b
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a r b i t r a _ e u r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: d
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a r b i t r a _ e u r '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: y
# Sever response: {'game_id': '8b9076c2aa73', 'status': 'failed', 'tries_remains': 0, 'word': 'a r b i t r a _ e u r '}
# Failed game: 8b9076c2aa73. Because of: # of tries exceeded!
# run 2457 practice games out of an allotted 100,000. practice success rate so far = 0.604
# 69  of 1000
# Successfully start a new game! Game ID: f9ce3b4478ea. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Guessing letter: e
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ s _ _ _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ s t _ _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ s t _ _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ s t _ _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ s t _ _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ s t _ _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: c
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a c _ s t _ _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: m
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a c _ s t _ _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: o
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a c _ s t _ o _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a c _ s t r o _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: h
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a c _ s t r o _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: k
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a c k s t r o k e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: b
# Sever response: {'game_id': 'f9ce3b4478ea', 'status': 'success', 'tries_remains': 1, 'word': 'b a c k s t r o k e s '}
# Successfully finished game: f9ce3b4478ea
# run 2458 practice games out of an allotted 100,000. practice success rate so far = 0.605
# 70  of 1000
# Successfully start a new game! Game ID: fa3098711673. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': 'fa3098711673', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': 'fa3098711673', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': 'fa3098711673', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': 'fa3098711673', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ e _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': 'fa3098711673', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': 'fa3098711673', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: l
# Sever response: {'game_id': 'fa3098711673', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ _ e s '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: v
# Sever response: {'game_id': 'fa3098711673', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ _ e s '}
# Failed game: fa3098711673. Because of: # of tries exceeded!
# run 2459 practice games out of an allotted 100,000. practice success rate so far = 0.604
# 71  of 1000
# Successfully start a new game! Game ID: 43fa643b1199. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: a
# Sever response: {'game_id': '43fa643b1199', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ a _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': '43fa643b1199', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ a _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: i
# Sever response: {'game_id': '43fa643b1199', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ a _ _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: n
# Sever response: {'game_id': '43fa643b1199', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ a _ _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: c
# Sever response: {'game_id': '43fa643b1199', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ a _ _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': '43fa643b1199', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ a _ _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: t
# Sever response: {'game_id': '43fa643b1199', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ a _ _ i _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: l
# Sever response: {'game_id': '43fa643b1199', 'status': 'failed', 'tries_remains': 0, 'word': 'a _ a _ _ i _ '}
# Failed game: 43fa643b1199. Because of: # of tries exceeded!
# run 2460 practice games out of an allotted 100,000. practice success rate so far = 0.604
# 72  of 1000
# Successfully start a new game! Game ID: a7a897d7fbf1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: e
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: t
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 4, 'word': 't _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: d
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't _ _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: r
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r _ _ _ _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r _ _ _ _ _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: i
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r i _ _ i _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: c
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r i c _ i _ a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: n
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r i c _ i n a _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: l
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r i c _ i n a l '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: h
# Sever response: {'game_id': 'a7a897d7fbf1', 'status': 'success', 'tries_remains': 3, 'word': 't r i c h i n a l '}
# Successfully finished game: a7a897d7fbf1
# run 2461 practice games out of an allotted 100,000. practice success rate so far = 0.604
# 73  of 1000
# Successfully start a new game! Game ID: c8929e114940. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: s
# Sever response: {'game_id': 'c8929e114940', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ s _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: t
# Sever response: {'game_id': 'c8929e114940', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ t s _ _ _ _ '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Guessing letter: e
# Sever response: {'game_id': 'c8929e114940', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ t s _ _ _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: a
# Sever response: {'game_id': 'c8929e114940', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e a _ t s _ a _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: r
# Sever response: {'game_id': 'c8929e114940', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e a r t s _ a _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: h
# Sever response: {'game_id': 'c8929e114940', 'status': 'ongoing', 'tries_remains': 6, 'word': 'h e a r t s h a _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: d
# Sever response: {'game_id': 'c8929e114940', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h e a r t s h a _ e '}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Guessing letter: k
